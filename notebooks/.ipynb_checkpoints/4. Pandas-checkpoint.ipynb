# %% [markdown]
# # Pandas
#
# https://pandas.pydata.org
#
# 1. Series y Dataframes
# 2. Query / iloc
# 3. csv, excel, sql

# %%
! pip install pandas
# Out:
# ...
# WARNING: You are using pip version 20.3.3; however, version 21.0.1 is available.
# You should consider upgrading via the 'c:\python39\python.exe -m pip install --upgrade pip' command.

# %% [markdown]
# ## Series
#
# 1. Son vectores o arreglos de numpy en transfondo
# 2. Es que se conceptualizan como columnas en un dataset
# 3. Pueden ser nombradas para unirse a dataframes

# %%
import pandas as pd # Importación de pandas con el alias pd

pd.Series([1, 2, 3, 4])
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
import numpy as np

x = pd.Series([1, 2, 3, 4])
y = x * 3 + np.sin(x)

y
# Out:
# 0     3.841471
# 1     6.909297
# 2     9.141120
# 3    11.243198
# dtype: float64

# %%
pd.Series([1, 2, 3, 4], name="Edades")
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# Name: Edades, dtype: int64

# %% [markdown]
# ## DataFrames
#
# 1. Son matrices en transfondo
# 2. Se conceptualizan como tablas (filas y columnas)
# 3. Podemos agrupar series como columnas

# %%
pd.DataFrame({
    "A": [1, 2, 3, 4],
    "B": [2, 6, 5, 3],
    "C": [False, True, False, False]
})
# Out:
#    A  B      C
# 0  1  2  False
# 1  2  6   True
# 2  3  5  False
# 3  4  3  False

# %%
A = pd.Series([1, 2, 3, 4], name="A")
B = A ** 2
B.name = "B"
C = B > 5
C.name = "C"

pd.DataFrame([A, B, C]).T
# Out:
#    A   B  C
# 0  1   1  0
# 1  2   4  0
# 2  3   9  1
# 3  4  16  1

# %%
pd.read_csv("datasets/demo.csv")
# Out:
#    A   B  C
# 0  1   1  0
# 1  1   4  0
# 2  1   9  1
# 3  1  16  1

# %%
data = pd.read_csv("datasets/country_vaccinations.csv")

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5140 entries, 0 to 5139
# Data columns (total 15 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   country                              5140 non-null   object
#  1   iso_code                             4816 non-null   object
#  2   date                                 5140 non-null   object
#  3   total_vaccinations                   3282 non-null   float64
#  4   people_vaccinated                    2856 non-null   float64
#  5   people_fully_vaccinated              1943 non-null   float64
#  6   daily_vaccinations_raw               2759 non-null   float64
#  7   daily_vaccinations                   4958 non-null   float64
#  8   total_vaccinations_per_hundred       3282 non-null   float64
#  9   people_vaccinated_per_hundred        2856 non-null   float64
#  10  people_fully_vaccinated_per_hundred  1943 non-null   float64
# ...

# %%
data
# Out:
#        country iso_code        date  total_vaccinations  people_vaccinated  \
# 0      Albania      ALB  2021-01-10                 0.0                0.0
# 1      Albania      ALB  2021-01-11                 NaN                NaN
# 2      Albania      ALB  2021-01-12               128.0              128.0
# 3      Albania      ALB  2021-01-13               188.0              188.0
# 4      Albania      ALB  2021-01-14               266.0              266.0
# ...        ...      ...         ...                 ...                ...
# 5135  Zimbabwe      ZWE  2021-02-28             18843.0            18843.0
# 5136  Zimbabwe      ZWE  2021-03-01             21456.0            21456.0
# 5137  Zimbabwe      ZWE  2021-03-02             25077.0            25077.0
# 5138  Zimbabwe      ZWE  2021-03-03             27970.0            27970.0
# 5139  Zimbabwe      ZWE  2021-03-04             30658.0            30658.0
#
# ...

# %%
set(data["country"])
# Out:
# {'Albania',
#  'Algeria',
#  'Andorra',
#  'Anguilla',
#  'Argentina',
#  'Australia',
#  'Austria',
#  'Azerbaijan',
#  'Bahrain',
#  'Bangladesh',
#  'Barbados',
#  'Belarus',
#  'Belgium',
#  'Bermuda',
#  'Bolivia',
#  'Brazil',
#  'Bulgaria',
#  'Cambodia',
#  'Canada',
#  'Cayman Islands',
#  'Chile',
#  'China',
#  'Colombia',
#  'Costa Rica',
#  'Croatia',
#  'Cyprus',
#  'Czechia',
#  'Denmark',
#  'Dominican Republic',
#  'Ecuador',
#  'Egypt',
#  'El Salvador',
#  'England',
#  'Estonia',
#  'Faeroe Islands',
#  'Falkland Islands',
#  'Finland',
#  'France',
#  'Germany',
#  'Gibraltar',
#  'Greece',
#  'Greenland',
#  'Guatemala',
#  'Guernsey',
#  'Guyana',
#  'Honduras',
#  'Hong Kong',
#  'Hungary',
#  'Iceland',
#  'India',
#  'Indonesia',
#  'Iran',
#  'Ireland',
#  'Isle of Man',
#  'Israel',
#  'Italy',
#  'Japan',
#  'Jersey',
#  'Jordan',
#  'Kazakhstan',
#  'Kuwait',
#  'Latvia',
#  'Lebanon',
#  'Liechtenstein',
#  'Lithuania',
#  'Luxembourg',
#  'Macao',
# ...

# %%
set(data["iso_code"])
# Out:
# {'AIA',
#  'ALB',
#  'AND',
#  'ARE',
#  'ARG',
#  'AUS',
#  'AUT',
#  'AZE',
#  'BEL',
#  'BGD',
#  'BGR',
#  'BHR',
#  'BLR',
#  'BMU',
#  'BOL',
#  'BRA',
#  'BRB',
#  'CAN',
#  'CHE',
#  'CHL',
#  'CHN',
#  'COL',
#  'CRI',
#  'CYM',
#  'CYP',
#  'CZE',
#  'DEU',
#  'DNK',
#  'DOM',
#  'DZA',
#  'ECU',
#  'EGY',
#  'ESP',
#  'EST',
#  'FIN',
#  'FLK',
#  'FRA',
#  'FRO',
#  'GBR',
#  'GGY',
#  'GIB',
#  'GRC',
#  'GRL',
#  'GTM',
#  'GUY',
#  'HKG',
#  'HND',
#  'HRV',
#  'HUN',
#  'IDN',
#  'IMN',
#  'IND',
#  'IRL',
#  'IRN',
#  'ISL',
#  'ISR',
#  'ITA',
#  'JEY',
#  'JOR',
#  'JPN',
#  'KAZ',
#  'KHM',
#  'KOR',
#  'KWT',
#  'LBN',
#  'LIE',
#  'LKA',
#  'LTU',
#  'LUX',
#  'LVA',
#  'MAC',
#  'MAR',
#  'MCO',
#  'MDV',
#  'MEX',
#  'MLT',
#  'MMR',
#  'MNE',
#  'MNG',
#  'MSR',
#  'MUS',
#  'MYS',
#  'NLD',
#  'NOR',
#  'NPL',
#  'NZL',
#  'OMN',
#  'OWID_NCY',
#  'PAK',
#  'PAN',
#  'PER',
#  'PHL',
#  'POL',
#  'PRT',
#  'PRY',
#  'QAT',
#  'ROU',
#  'RUS',
#  'SAU',
# ...

# %%
data_mex = data.query("iso_code == 'MEX'")

data_mex
# Out:
#      country iso_code        date  total_vaccinations  people_vaccinated  \
# 3153  Mexico      MEX  2020-12-24              2924.0             2924.0
# 3154  Mexico      MEX  2020-12-25                 NaN                NaN
# 3155  Mexico      MEX  2020-12-26                 NaN                NaN
# 3156  Mexico      MEX  2020-12-27              6824.0             6824.0
# 3157  Mexico      MEX  2020-12-28              9579.0             9579.0
# ...      ...      ...         ...                 ...                ...
# 3219  Mexico      MEX  2021-02-28           2455095.0          1889672.0
# 3220  Mexico      MEX  2021-03-01           2526863.0          1959525.0
# 3221  Mexico      MEX  2021-03-02           2583435.0          2012853.0
# 3222  Mexico      MEX  2021-03-03           2633580.0          2043941.0
# 3223  Mexico      MEX  2021-03-04           2676035.0                NaN
#
#       people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# ...

# %%
len(data_mex)
# Out:
# 71

# %%
data_mex.dropna()
# Out:
#      country iso_code        date  total_vaccinations  people_vaccinated  \
# 3175  Mexico      MEX  2021-01-15            417375.0           415417.0
# 3176  Mexico      MEX  2021-01-16            463246.0           461025.0
# 3177  Mexico      MEX  2021-01-17            472142.0           468708.0
# 3178  Mexico      MEX  2021-01-18            492529.0           485983.0
# 3179  Mexico      MEX  2021-01-19            498122.0           488513.0
# 3180  Mexico      MEX  2021-01-20            501030.0           489628.0
# 3181  Mexico      MEX  2021-01-21            552335.0           534317.0
# 3182  Mexico      MEX  2021-01-22            614808.0           594725.0
# 3183  Mexico      MEX  2021-01-23            618768.0           596296.0
# 3184  Mexico      MEX  2021-01-24            629626.0           604441.0
# 3185  Mexico      MEX  2021-01-25            645105.0           616390.0
# 3186  Mexico      MEX  2021-01-26            652319.0           621005.0
# ...

# %%
mex = pd.DataFrame({
    "date": data_mex["date"],
    "total_vaccinations": data_mex["total_vaccinations"],
    "people_vaccinated": data_mex["people_vaccinated"],
}).dropna()

mex
# Out:
#             date  total_vaccinations  people_vaccinated
# 3153  2020-12-24              2924.0             2924.0
# 3156  2020-12-27              6824.0             6824.0
# 3157  2020-12-28              9579.0             9579.0
# 3158  2020-12-29             18529.0            18529.0
# 3159  2020-12-30             24998.0            24998.0
# ...          ...                 ...                ...
# 3218  2021-02-27           2383411.0          1818034.0
# 3219  2021-02-28           2455095.0          1889672.0
# 3220  2021-03-01           2526863.0          1959525.0
# 3221  2021-03-02           2583435.0          2012853.0
# 3222  2021-03-03           2633580.0          2043941.0
#
# [62 rows x 3 columns]

# %%
import matplotlib.pyplot as plt

plt.bar(mex["date"][:30], mex["total_vaccinations"][:30])

plt.xticks(rotation=90)

plt.show()

# %%
plt.bar(mex["date"][30:], mex["total_vaccinations"][30:])

plt.xticks(rotation=90)

plt.show()

# %%
mex.query("date >= '2021-01-01' and date < '2021-02-01'")
# Out:
#             date  total_vaccinations  people_vaccinated
# 3164  2021-01-04             43960.0            43960.0
# 3165  2021-01-05             48236.0            48236.0
# 3166  2021-01-06             53185.0            53185.0
# 3167  2021-01-07             58402.0            58402.0
# 3168  2021-01-08             67468.0            67468.0
# 3169  2021-01-09             74794.0            74794.0
# 3170  2021-01-10             81300.0            81300.0
# 3171  2021-01-11             87060.0            87060.0
# 3172  2021-01-12             92879.0            92879.0
# 3173  2021-01-13            192567.0           192567.0
# 3174  2021-01-14            329983.0           329983.0
# 3175  2021-01-15            417375.0           415417.0
# 3176  2021-01-16            463246.0           461025.0
# 3177  2021-01-17            472142.0           468708.0
# 3178  2021-01-18            492529.0           485983.0
# 3179  2021-01-19            498122.0           488513.0
# ...

# %%
def is_date_odd(date):
    # TODO: Calcular si una fecha es fin de semana
    return int(date[-2:]) % 2 == 1

mex["date_is_odd"] = mex["date"].map(is_date_odd)

mex
# Out:
#             date  total_vaccinations  people_vaccinated  date_is_saturday  \
# 3153  2020-12-24              2924.0             2924.0              True
# 3156  2020-12-27              6824.0             6824.0              True
# 3157  2020-12-28              9579.0             9579.0              True
# 3158  2020-12-29             18529.0            18529.0              True
# 3159  2020-12-30             24998.0            24998.0              True
# ...          ...                 ...                ...               ...
# 3218  2021-02-27           2383411.0          1818034.0              True
# 3219  2021-02-28           2455095.0          1889672.0              True
# 3220  2021-03-01           2526863.0          1959525.0              True
# 3221  2021-03-02           2583435.0          2012853.0              True
# 3222  2021-03-03           2633580.0          2043941.0              True
#
#       date_is_odd
# 3153        False
# 3156         True
# 3157        False
# ...

# %%
mex.query("date_is_odd")
# Out:
#             date  total_vaccinations  people_vaccinated  date_is_saturday  \
# 3156  2020-12-27              6824.0             6824.0              True
# 3158  2020-12-29             18529.0            18529.0              True
# 3165  2021-01-05             48236.0            48236.0              True
# 3167  2021-01-07             58402.0            58402.0              True
# 3169  2021-01-09             74794.0            74794.0              True
# 3171  2021-01-11             87060.0            87060.0              True
# 3173  2021-01-13            192567.0           192567.0              True
# 3175  2021-01-15            417375.0           415417.0              True
# 3177  2021-01-17            472142.0           468708.0              True
# 3179  2021-01-19            498122.0           488513.0              True
# 3181  2021-01-21            552335.0           534317.0              True
# 3183  2021-01-23            618768.0           596296.0              True
# ...
