# %%
f = open("datasets/knight-moves.txt")

for line in f:
    parts = line.split(" ")
    print(parts)

f.close()
# Out:
# *', 'c*', 'd*', 'c+', 'LUU\n']
# ['c*', 'd+', 'c+', 'x', 'p+', 'x', 'r*', 't*', 'LLU\n']
# ['r+', 'p*', 'a*', 'c*', 'p+', 't*', 'd*', 'r*', 'LUU\n']
# ['p+', 'x', '-', 'c*', 'a+', 'p*', 'p+', 'd+', 'RUU\n']
# ['r+', 'r*', 'c*', 't+', 'a+', 'a+', 'p*', 'd*', 'LUU\n']
# ['x', 'd+', 'd*', 'x', 'r+', 'p+', 'd*', 'p*', 'RDD\n']
# ['c*', 'd+', 't+', 'r*', 'r*', 'r*', 'x', 'c+', 'LLU\n']
# ['t*', 'a+', 'd+', 'c+', '-', 't+', 'c*', 'p+', 'LLD\n']
# ['a*', 'd*', 'd+', 'p+', 'd*', 't*', 'a*', 'p+', 'LLD\n']
# ['a*', 'd*', 'r+', 'c+', 'r+', 'r*', 'd+', 'd+', 'RDD\n']
# ['p*', 'c*', 'x', 'r+', 'a+', 'd*', 'p*', 't+', 'LDD\n']
# ['p+', 'c+', 'c+', 'a*', 'd+', 't+', 't*', 't+', 'RDD\n']
# ['p+', 'r+', 't*', 't*', 'd+', 'x', 'a+', '-', 'LLU\n']
# ['r+', 'p+', 'x', 'd+', 'd+', 'r+', 'd+', 't*', 'RRD\n']
# ['p+', 'a*', '-', 'r+', 'c+', 'd+', 'c*', 'c+', 'LDD\n']
# ['d*', 'c*', 'x', 't*', 'd+', 'p*', 't*', 'c*', 'RDD\n']
# ['x', 'r*', 'd*', 'p*', 'r+', 'r*', 'c+', 'p*', 'RDD\n']
# ...
